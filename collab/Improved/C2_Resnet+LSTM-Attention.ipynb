# %%
from google.colab import drive
import pickle
import pandas as pd
from collections import defaultdict
import random
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import os
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
import timm
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install rouge_score
# Out:
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge_score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->rouge_score) (4.67.3)

# %%
# !pip install pycocoevalcap
# Out:
# Requirement already satisfied: pycocoevalcap in /usr/local/lib/python3.12/dist-packages (1.2)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from pycocoevalcap) (2.0.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pycocotools>=2.0.2->pycocoevalcap) (2.0.2)

# %%
import nltk
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer

from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.spice.spice import Spice

import pandas as pd
import torch

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
# Copying 8k to Colabs local SSD
if not os.path.exists("/content/flickr8k.zip"):
  # !cp -r "/content/drive/MyDrive/MMRetrieval/flickr8k.zip" /content/

# %%
if not os.path.isdir("/content/flickr8k/Images"):
  # !unzip "/content/flickr8k.zip" -d "/content/flickr8k"

# %%
print("Images:", len(os.listdir("/content/flickr8k/Images")))
# Out:
# Images: 8091

# %%
# Copying 30k to Colabs local SSD
if not os.path.exists("/content/flickr30k.zip"):
  # !cp -r "/content/drive/MyDrive/MMRetrieval/flickr30k.zip" /content/

# %%
if not os.path.isdir("/content/flickr30k/Images"):
  # !unzip "/content/flickr30k.zip" -d "/content/flickr30k"

# %%
print("Images:", len(os.listdir("/content/flickr30k/Images")))
# Out:
# Images: 31811

# %%
DATASETS = {
    "flickr8k": {
        "ROOT": "/content/flickr8k",
        "IMAGE_DIR": "/content/flickr8k/Images",
        "CAPTION_FILE": "/content/flickr8k/captions.txt",
        "flickr_split": "/content/drive/MyDrive/MMRetrieval/Preprocessing/flickr8k/flickr8k_split.pkl",
        "vocab":"/content/drive/MyDrive/MMRetrieval/Preprocessing/flickr8k/vocab.pkl"
    },
    "flickr30k": {
        "ROOT": "/content/flickr30k",
        "IMAGE_DIR": "/content/flickr30k/Images",
        "CAPTION_FILE": "/content/flickr30k/captions.txt",
        "flickr_split": "/content/drive/MyDrive/MMRetrieval/Preprocessing/flickr30k/flickr30k_split.pkl",
        "vocab":"/content/drive/MyDrive/MMRetrieval/Preprocessing/flickr30k/vocab.pkl"
    }
}

# %%
def image_caption_map(train_df,val_df,test_df):
  train_caption_map = defaultdict(list)
  val_caption_map = defaultdict(list)
  test_caption_map = defaultdict(list)

  bad_img = "861608773_bdafd5c996.jpg"

  train_caption_map.pop(bad_img, None)
  val_caption_map.pop(bad_img, None)
  test_caption_map.pop(bad_img, None)

  for _, row in train_df.iterrows():
      train_caption_map[row["image"]].append(row["caption"])

  for _, row in val_df.iterrows():
      val_caption_map[row["image"]].append(row["caption"])

  for _, row in test_df.iterrows():
      test_caption_map[row["image"]].append(row["caption"])
  return train_caption_map,val_caption_map,test_caption_map

# %%
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomResizedCrop(
        224,
        scale=(0.8, 1.0),
        ratio=(0.9, 1.1)
    ),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.2,
        hue=0.05
    ),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485,0.456,0.406],
        std=[0.229,0.224,0.225]
    )
])

# %%
image_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
# Encoding

def encode_caption(text, vocab):

    tokens = text.split()

    encoded = [vocab["<SOS>"]]

    for token in tokens:
        encoded.append(
            vocab.get(token, vocab["<UNK>"])
        )

    encoded.append(vocab["<EOS>"])

    return encoded

# %%
class FlickrCaptionDataset(Dataset):

    def __init__(
            self,
            caption_map,
            image_dir,
            vocab,
            transform=None,
            random_caption=True):

        self.image_names = sorted(caption_map.keys())
        self.caption_map = caption_map
        self.image_dir = image_dir
        self.vocab = vocab
        self.transform = transform
        self.random_caption = random_caption

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):

        image_name = self.image_names[idx]

        captions = self.caption_map[image_name]

        if self.random_caption:
            caption = random.choice(captions)
        else:
            caption = captions[0]

        try:
            image = Image.open(
                os.path.join(self.image_dir, image_name)
            ).convert("RGB")
        except Exception:
            return self.__getitem__((idx + 1) % len(self))

        if self.transform:
            image = self.transform(image)

        caption = encode_caption(caption, self.vocab)

        input_caption = torch.tensor(
            caption[:-1],
            dtype=torch.long
        )

        target_caption = torch.tensor(
            caption[1:],
            dtype=torch.long
        )

        return image, input_caption, target_caption

# %%
from torch.utils.data import Dataset
from PIL import Image
import os

class FlickrCaptionTestDataset(Dataset):

    def __init__(
            self,
            caption_map,
            image_dir,
            transform=None
    ):

        self.image_names = sorted(caption_map.keys())
        self.caption_map = caption_map
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.image_names)

    def __getitem__(self, idx):

        image_name = self.image_names[idx]

        # List containing all 5 captions
        captions = self.caption_map[image_name]

        try:
            image = Image.open(
                os.path.join(self.image_dir, image_name)
            ).convert("RGB")

        except Exception:
            return self.__getitem__(
                (idx + 1) % len(self)
            )

        if self.transform:
            image = self.transform(image)

        return image, captions

# %%
from torch.nn.utils.rnn import pad_sequence

def collate_fn(batch):

    images = []
    input_captions = []
    target_captions_list = []

    for image, input_caption, target_caption in batch:
        images.append(image)
        input_captions.append(input_caption)
        target_captions_list.append(target_caption)

    images = torch.stack(images)

    input_captions = pad_sequence(
        input_captions,
        batch_first=True,
        padding_value=vocab["<PAD>"]
    )

    padded_target_captions = pad_sequence(
        target_captions_list,
        batch_first=True,
        padding_value=vocab["<PAD>"]
    )

    return images, input_captions, padded_target_captions

# %%
#Encoder
class ResnetAttentionEncoder(nn.Module):

    def __init__(self, embed_dim=512):

        super().__init__()

        backbone = models.resnet50(
            weights=models.ResNet50_Weights.IMAGENET1K_V2
        )

        for param in backbone.parameters():
            param.requires_grad = False

        for param in backbone.layer3.parameters():
            param.requires_grad = True

        for param in backbone.layer4.parameters():
            param.requires_grad = True

        self.backbone = nn.Sequential(
            *list(backbone.children())[:-2]
        )

        self.projection = nn.Sequential(
            nn.Linear(2048,1024),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(1024,embed_dim),
            nn.LayerNorm(embed_dim)
        )
        for m in self.projection:
          if isinstance(m, nn.Linear):
              nn.init.xavier_uniform_(m.weight)
              nn.init.zeros_(m.bias)

    def forward(self, images):

        features = self.backbone(images)

        # (B,2048,7,7)

        features = features.flatten(2)

        # (B,2048,49)

        features = features.permute(0,2,1)

        # (B,49,2048)

        features = self.projection(features)

        # (B,49,512)

        return features

# %%
class BahdanauAttention(nn.Module):

    def __init__(
        self,
        encoder_dim=512,
        decoder_dim=512,
        attention_dim=512
    ):
        super().__init__()

        self.encoder_att = nn.Linear(
            encoder_dim,
            attention_dim
        )

        self.decoder_att = nn.Linear(
            decoder_dim,
            attention_dim
        )
        self.attn_dropout = nn.Dropout(0.1)

        self.full_att = nn.Linear(
            attention_dim,
            1
        )
        self.context_dropout = nn.Dropout(0.1)

    def forward(self, encoder_outputs, hidden_state):

        encoder_projection = self.encoder_att(encoder_outputs)
        decoder_projection = self.decoder_att(hidden_state).unsqueeze(1)

        energy = torch.tanh(
            encoder_projection + decoder_projection
        )

        attention = self.full_att(energy).squeeze(2)

        alpha = F.softmax(attention, dim=1)
        alpha = self.attn_dropout(alpha)
        alpha = alpha / alpha.sum(dim=1, keepdim=True)

        context = torch.sum(
            encoder_outputs * alpha.unsqueeze(2),
            dim=1
        )

        context = self.context_dropout(context)

        return context, alpha

# %%
#Decoder
class AttentionLSTMDecoder(nn.Module):

    def __init__(
        self,
        vocab_size,
        embed_dim=512,
        hidden_dim=512,
        encoder_dim=512,
        attention_dim=512,
        pad_idx=0
    ):

        super().__init__()

        self.embedding = nn.Embedding(
            vocab_size,
            embed_dim,
            padding_idx=pad_idx
        )

        self.attention = BahdanauAttention(
            encoder_dim=encoder_dim,
            decoder_dim=hidden_dim,
            attention_dim=attention_dim
        )

        self.lstm = nn.LSTMCell(
            input_size=embed_dim + encoder_dim,
            hidden_size=hidden_dim
        )

        self.fc = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dim, vocab_size)
        )

        self.init_h = nn.Linear(
            encoder_dim,
            hidden_dim
        )

        self.init_c = nn.Linear(
            encoder_dim,
            hidden_dim
        )
        self.h_norm = nn.LayerNorm(hidden_dim)
        self.c_norm = nn.LayerNorm(hidden_dim)


        self.dropout = nn.Dropout(0.2)
        nn.init.xavier_uniform_(self.embedding.weight)

        with torch.no_grad():
            self.embedding.weight[pad_idx].fill_(0)

        for m in self.modules():
          if isinstance(m, nn.Linear):
              nn.init.xavier_uniform_(m.weight)
              nn.init.zeros_(m.bias)

        for name, param in self.lstm.named_parameters():
          if "weight_ih" in name:
              nn.init.xavier_uniform_(param)

          elif "weight_hh" in name:
              nn.init.orthogonal_(param)

          elif "bias" in name:
              nn.init.zeros_(param)


    def forward(
        self,
        encoder_outputs,
        captions
    ):

        # encoder_outputs
        # (B,49,512)

        embeddings = self.embedding(
            captions
        )


        seq_len = captions.size(1)

        mean_encoder = encoder_outputs.mean(dim=1)

        h = torch.tanh(
            self.h_norm(
                self.init_h(mean_encoder)
            )
        )

        c = torch.tanh(
            self.c_norm(
                self.init_c(mean_encoder)
            )
        )

        outputs = []

        for t in range(seq_len):

            context, alpha = self.attention(
                encoder_outputs,
                h
            )

            lstm_input = torch.cat(
                (
                    embeddings[:, t],
                    context
                ),
                dim=1
            )

            h, c = self.lstm(
                lstm_input,
                (h, c)
            )

            scores = self.fc(
                self.dropout(h)
            )

            outputs.append(scores)

        outputs = torch.stack(
            outputs,
            dim=1
        )

        return outputs

# %%
#Joint model
class ResnetAttentionCaptioningModel(nn.Module):

    def __init__(self, encoder, decoder):
        super().__init__()

        self.encoder = encoder
        self.decoder = decoder

    def forward(self, images, captions):

        encoder_outputs = self.encoder(images)

        outputs = self.decoder(
            encoder_outputs,
            captions
        )

        return outputs
    @staticmethod
    def length_penalty(length, alpha=0.7):
        return ((5 + length) ** alpha) / ((5 + 1) ** alpha)


    def generate_caption(
    self,
    images,
    vocab,
    max_length=30,
    beam_size=3
    ):

        self.eval()

        idx2word = {v: k for k, v in vocab.items()}
        batch_size = images.size(0)

        assert batch_size == 1, "Beam search currently supports batch_size=1."

        with torch.no_grad():

            encoder_outputs = self.encoder(images)

            mean_encoder = encoder_outputs.mean(dim=1)

            h = torch.tanh(
                self.decoder.h_norm(
                    self.decoder.init_h(mean_encoder)
                )
            )

            c = torch.tanh(
                self.decoder.c_norm(
                    self.decoder.init_c(mean_encoder)
                )
            )

            beams = [(
                [vocab["<SOS>"]],
                0.0,
                h,
                c
            )]

            completed = []

            for step in range(max_length):

                candidates = []

                for seq, score, h_beam, c_beam in beams:

                    last_token = seq[-1]

                    if last_token == vocab["<EOS>"]:
                        completed.append((seq, score))
                        continue

                    current_word = torch.tensor(
                        [last_token],
                        device=images.device
                    )

                    embedding = self.decoder.embedding(current_word)

                    context, _ = self.decoder.attention(
                        encoder_outputs,
                        h_beam
                    )

                    lstm_input = torch.cat(
                        [embedding, context],
                        dim=1
                    )


                    # LSTM step
                    h_new, c_new = self.decoder.lstm(
                        lstm_input,
                        (h_beam, c_beam)
                    )


                    # Vocabulary prediction
                    scores = self.decoder.fc(
                        self.decoder.dropout(h_new)
                    )


                    # Block invalid tokens
                    scores[:, vocab["<PAD>"]] = -1e9
                    scores[:, vocab["<SOS>"]] = -1e9
                    scores[:, vocab["<UNK>"]] = -1e9


                    # Avoid immediate EOS
                    if step < 5:
                        scores[:, vocab["<EOS>"]] = -1e9


                    log_probs = F.log_softmax(scores, dim=1)

                    top_log_probs, top_indices = torch.topk(
                        log_probs,
                        beam_size,
                        dim=1
                    )

                    for k in range(beam_size):

                        token = top_indices[0, k].item()

                        new_seq = seq + [token]

                        new_score = score + top_log_probs[0, k].item()

                        candidates.append(
                            (
                                new_seq,
                                new_score,
                                h_new.clone(),
                                c_new.clone()
                            )
                        )

                if len(candidates) == 0:
                    break

                candidates = sorted(
                    candidates,
                    key=lambda x: x[1] / self.length_penalty(len(x[0])),
                    reverse=True
                )

                beams = candidates[:beam_size]

                for beam in beams:
                    if beam[0][-1] == vocab["<EOS>"]:
                        completed.append(
                            (beam[0], beam[1])
                        )

            if len(completed) == 0:
                completed = [(beams[0][0], beams[0][1])]

            completed = sorted(
                completed,
                key=lambda x: x[1] / self.length_penalty(len(x[0])),
                reverse=True
            )

            best_seq = completed[0][0]

            return [best_seq[1:]]

# %%
def build_image_text_decoder(vocab, device):

    encoder = ResnetAttentionEncoder(embed_dim=512)

    decoder = AttentionLSTMDecoder(
        vocab_size=len(vocab),
        embed_dim=512,
        hidden_dim=512,
        encoder_dim=512,
        pad_idx=vocab["<PAD>"]
    )

    model = ResnetAttentionCaptioningModel(
        encoder,
        decoder
    ).to(device)

    return model

# %%
def define_optimizer(model):

    optimizer = torch.optim.AdamW(
        [
            # Fine-tune only trainable ResNet layers
            {
                "params": filter(
                    lambda p: p.requires_grad,
                    model.encoder.backbone.parameters()
                ),
                "lr": 1e-5
            },

            # Projection head
            {
                "params": model.encoder.projection.parameters(),
                "lr": 3e-4
            },

            # Single-layer LSTM decoder
            {
                "params": model.decoder.parameters(),
                "lr": 2e-4
            }
        ],
        weight_decay=1e-4
    )

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=50
    )

    return optimizer, scheduler

# %%
def evaluate(model, dataloader, criterion, device):

    model.eval()

    total_loss = 0.0
    total_samples = 0

    with torch.no_grad():

        for images, input_captions, target_captions in dataloader:

            images = images.to(device)
            input_captions = input_captions.to(device)
            target_captions = target_captions.to(device)

            device_type = images.device.type

            with torch.autocast(
                device_type=device_type,
                enabled=(device_type == "cuda")
            ):

                outputs = model(
                    images,
                    input_captions
                )

                loss = criterion(
                    outputs.reshape(-1, outputs.size(-1)),
                    target_captions.reshape(-1)
                )

            total_loss += loss.item() * images.size(0)
            total_samples += images.size(0)

    avg_loss = total_loss / total_samples
    perplexity = torch.exp(torch.tensor(avg_loss)).item()

    return avg_loss, perplexity

# %%
import os
import time
import torch
import torch.nn as nn

def model_training(
        model,
        train_loader,
        val_loader,
        optimizer,
        scheduler,
        criterion,
        dataset_name):

    NUM_EPOCHS = 50

    best_val_loss = float("inf")

    patience = 8
    epochs_without_improvement = 0

    SAVE_DIR = f"/content/drive/MyDrive/MMCaptioning/C2/{dataset_name}"
    os.makedirs(SAVE_DIR, exist_ok=True)

    BEST_MODEL_PATH = os.path.join(
        SAVE_DIR,
        "best_captioning_C2_model.pth"
    )

    for epoch in range(NUM_EPOCHS):

        print(f"\n================ Epoch {epoch+1}/{NUM_EPOCHS} ================")

        model.train()

        running_loss = 0.0

        epoch_start = time.time()

        for batch_idx, (images, input_captions, target_captions) in enumerate(train_loader):

            batch_start = time.time()

            images = images.to(device, non_blocking=True)
            input_captions = input_captions.to(device, non_blocking=True)
            target_captions = target_captions.to(device, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            outputs = model(
                images,
                input_captions
            )

            loss = criterion(
                outputs.reshape(-1, outputs.size(-1)),
                target_captions.reshape(-1)
            )

            loss.backward()
            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                1.0
            )

            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                max_norm=1.0
            )

            optimizer.step()

            running_loss += loss.item()

            print(
                f"Batch {batch_idx+1:03d}/{len(train_loader)} | "
                f"Loss: {loss.item():.4f} | "
                f"Time: {time.time()-batch_start:.2f}s"
            )

        train_loss = running_loss / len(train_loader)

        train_time = time.time() - epoch_start

        # Validation

        val_start = time.time()

        val_loss, val_perplexity = evaluate(
            model,
            val_loader,
            criterion,
            device
        )

        scheduler.step()

        val_time = time.time() - val_start

        print("\n---------------- Summary ----------------")

        print(f"Train Loss      : {train_loss:.4f}")
        print(f"Validation Loss : {val_loss:.4f}")
        print(f"Perplexity      : {val_perplexity:.2f}")
        print(f"Training Time   : {train_time:.2f}s")
        print(f"Validation Time : {val_time:.2f}s")

        print(
            f"GPU Memory Used : "
            f"{torch.cuda.memory_allocated()/1024**3:.2f} GB"
        )

        # Save Best

        if val_loss < best_val_loss:

            best_val_loss = val_loss
            epochs_without_improvement = 0

            torch.save(
                {
                    "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "scheduler_state_dict": scheduler.state_dict(),
                    "epoch": epoch,
                    "val_loss": val_loss
                },
                BEST_MODEL_PATH
            )

            print(f"✓ Best model saved (Val Loss: {val_loss:.4f})")

        else:

            epochs_without_improvement += 1

            print(
                f"No improvement for "
                f"{epochs_without_improvement}/{patience} epochs"
            )

        if epochs_without_improvement >= patience:

            print("\nEarly stopping triggered!")

            break

    checkpoint = torch.load(
        BEST_MODEL_PATH,
        map_location=device
    )

    model.load_state_dict(
        checkpoint["model_state_dict"]
    )

    return model, BEST_MODEL_PATH

# %%
import gc
def reset_resources():
  gc.collect()
  torch.cuda.empty_cache()
  print("\nMemory after cleanup")
  print("Allocated:",torch.cuda.memory_allocated()/1024**3)
  print("Reserved:",torch.cuda.memory_reserved()/1024**3)

# %%
def caption_test_collate_fn(batch):

    images = []
    all_references = []

    for image, references in batch:
        images.append(image)
        all_references.append(references)

    images = torch.stack(images)

    return images, all_references

# %%
def prepare_caption_dataloaders(
        train_caption_map,
        val_caption_map,
        test_caption_map):

    BATCH_SIZE = 192

    train_dataset = FlickrCaptionDataset(
        train_caption_map,
        IMAGE_DIR,
        vocab,
        train_transform,
        random_caption=True
    )

    val_dataset = FlickrCaptionDataset(
        val_caption_map,
        IMAGE_DIR,
        vocab,
        image_transform,
        random_caption=False
    )

    # Different dataset for evaluation
    test_dataset = FlickrCaptionTestDataset(
        test_caption_map,
        IMAGE_DIR,
        image_transform
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        collate_fn=collate_fn,
        num_workers=8,
        pin_memory=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        collate_fn=collate_fn,
        num_workers=8,
        pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        collate_fn=caption_test_collate_fn,   # Different collate function
        num_workers=8,
        pin_memory=True
    )

    return train_loader, val_loader, test_loader

# %%
def model_testing(model,checkpoint_path,test_loader,vocab,device):
  checkpoint = torch.load(checkpoint_path,map_location=device)
  model.load_state_dict(checkpoint["model_state_dict"])
  model.to(device)
  model.eval()



  idx2word = {v: k for k, v in vocab.items()}

  references = []
  predictions = []

  rouge = rouge_scorer.RougeScorer(["rougeL"],use_stemmer=True)

  rouge_scores = []
  meteor_scores = []

  coco_refs = {}
  coco_preds = {}

  sample_id = 0

  print("Generating captions...")

  with torch.inference_mode():

      for images, all_references in test_loader:

        images = images.to(device)   # move BEFORE running encoder

        predicted_ids = []

        for j in range(images.size(0)):
            pred = model.generate_caption(
                images[j:j+1],
                vocab,
                max_length=30,
                beam_size=3
            )
            predicted_ids.extend(pred)
        for i in range(images.size(0)):
            # Prediction
            pred_words = []
            for idx in predicted_ids[i]:
                word = idx2word[idx]
                if word == "<EOS>":
                    break
                if word not in ["<SOS>", "<PAD>"]:
                    pred_words.append(word)

            pred_sentence = " ".join(pred_words)

            # References (5 captions)
            ref_words = [ref.split() for ref in all_references[i]]
            references.append(ref_words)
            predictions.append(pred_words)

            # ROUGE-L
            rouge_values = []

            for ref in all_references[i]:

                rouge_values.append(rouge.score(ref,pred_sentence)["rougeL"].fmeasure)

            rouge_scores.append(max(rouge_values))

            # METEOR
            meteor_scores.append(meteor_score(ref_words,pred_words))

            # COCO format
            coco_refs[sample_id] = [str(ref) for ref in all_references[i]]

            coco_preds[sample_id] = [str(pred_sentence)]

            sample_id += 1

  # BLEU
  smoothie = SmoothingFunction().method4
  bleu1 = corpus_bleu(references,predictions,weights=(1,0,0,0),smoothing_function=smoothie)

  bleu2 = corpus_bleu(references,predictions,weights=(0.5,0.5,0,0),smoothing_function=smoothie)

  bleu3 = corpus_bleu(references,predictions,weights=(0.33,0.33,0.33,0),smoothing_function=smoothie)

  bleu4 = corpus_bleu(references,predictions,weights=(0.25,0.25,0.25,0.25),smoothing_function=smoothie)

  # CIDEr
  cider_scorer = Cider()

  cider_score, _ = cider_scorer.compute_score(coco_refs,coco_preds)

  # SPICE

  # Results

  results = pd.DataFrame({

      "Metric":[
          "BLEU-1",
          "BLEU-2",
          "BLEU-3",
          "BLEU-4",
          "ROUGE-L",
          "METEOR",
          "CIDEr",

      ],

      "Score":[
          bleu1,
          bleu2,
          bleu3,
          bleu4,
          sum(rouge_scores)/len(rouge_scores),
          sum(meteor_scores)/len(meteor_scores),
          cider_score,

      ]

  })
  print(coco_refs[0])
  print(coco_preds[0])
  display(results)

  return results

# %%
for dataset_name, cfg in DATASETS.items():

    torch.cuda.reset_peak_memory_stats()

    print("\n************************")
    print(f"\nProcessing - {dataset_name}")
    print("\n************************\n")

    ROOT = cfg["ROOT"]
    IMAGE_DIR = cfg["IMAGE_DIR"]
    CAPTION_FILE = cfg["CAPTION_FILE"]

    with open(cfg["flickr_split"], "rb") as f:
        split = pickle.load(f)

    with open(cfg["vocab"], "rb") as f:
        vocab = pickle.load(f)


    #Build Model

    model = build_image_text_decoder(
        vocab,
        device
    )

    optimizer, scheduler = define_optimizer(model)

    # Dataset

    df = pd.read_csv(CAPTION_FILE)

    train_imgs = split["train"]
    val_imgs = split["val"]
    test_imgs = split["test"]

    print(
        f"Train: {len(train_imgs)} | "
        f"Val: {len(val_imgs)} | "
        f"Test: {len(test_imgs)}"
    )

    train_df = df[df["image"].isin(train_imgs)].reset_index(drop=True)
    val_df = df[df["image"].isin(val_imgs)].reset_index(drop=True)
    test_df = df[df["image"].isin(test_imgs)].reset_index(drop=True)

    train_df = train_df.dropna(subset=["caption"]).reset_index(drop=True)
    val_df = val_df.dropna(subset=["caption"]).reset_index(drop=True)
    test_df = test_df.dropna(subset=["caption"]).reset_index(drop=True)

    train_caption_map, val_caption_map, test_caption_map = image_caption_map(
        train_df,
        val_df,
        test_df
    )

    train_loader, val_loader, test_loader = prepare_caption_dataloaders(
        train_caption_map,
        val_caption_map,
        test_caption_map
    )
    criterion = nn.CrossEntropyLoss(ignore_index=vocab["<PAD>"],label_smoothing=0.1)

    #Train

    best_model, FINAL_MODEL_PATH = model_training(
        model,
        train_loader,
        val_loader,
        optimizer,
        scheduler,
        criterion,
        dataset_name
    )

    #Test

    model_testing(
        best_model,
        FINAL_MODEL_PATH,
        test_loader,
        vocab,
        device
    )

    # Cleanup

    del model
    del optimizer
    del scheduler

    del train_loader
    del val_loader
    del test_loader

    del train_df
    del val_df
    del test_df

    del train_caption_map
    del val_caption_map
    del test_caption_map

    del split
    del vocab
    del df

    reset_resources()
# Out:
# ************************
#
# Processing - flickr8k
#
# ************************
#
# Train: 6068 | Val: 1011 | Test: 1012
#
# ================ Epoch 1/50 ================
# Batch 001/32 | Loss: 7.8598 | Time: 0.20s
# Batch 002/32 | Loss: 7.7886 | Time: 0.18s
# Batch 003/32 | Loss: 7.7152 | Time: 0.17s
# Batch 004/32 | Loss: 7.6214 | Time: 0.18s
# Batch 005/32 | Loss: 7.5318 | Time: 0.19s
# Batch 006/32 | Loss: 7.4062 | Time: 0.18s
# Batch 007/32 | Loss: 7.2808 | Time: 0.18s
# Batch 008/32 | Loss: 7.1223 | Time: 0.17s
# Batch 009/32 | Loss: 6.9562 | Time: 0.22s
# Batch 010/32 | Loss: 6.7924 | Time: 0.19s
# Batch 011/32 | Loss: 6.5787 | Time: 0.19s
# Batch 012/32 | Loss: 6.4027 | Time: 0.18s
# Batch 013/32 | Loss: 6.2361 | Time: 0.18s
# Batch 014/32 | Loss: 6.1333 | Time: 0.18s
# Batch 015/32 | Loss: 6.0248 | Time: 0.18s
# Batch 016/32 | Loss: 5.9241 | Time: 0.17s
# Batch 017/32 | Loss: 5.7955 | Time: 0.20s
# Batch 018/32 | Loss: 5.7653 | Time: 0.18s
# Batch 019/32 | Loss: 5.6279 | Time: 0.18s
# Batch 020/32 | Loss: 5.5948 | Time: 0.17s
# Batch 021/32 | Loss: 5.5647 | Time: 0.19s
# Batch 022/32 | Loss: 5.5119 | Time: 0.17s
# Batch 023/32 | Loss: 5.5359 | Time: 0.17s
# Batch 024/32 | Loss: 5.5011 | Time: 0.20s
# Batch 025/32 | Loss: 5.5019 | Time: 0.19s
# Batch 026/32 | Loss: 5.3794 | Time: 0.17s
# Batch 027/32 | Loss: 5.3662 | Time: 0.17s
# Batch 028/32 | Loss: 5.3897 | Time: 0.17s
# Batch 029/32 | Loss: 5.2814 | Time: 0.17s
# Batch 030/32 | Loss: 5.3612 | Time: 0.17s
# Batch 031/32 | Loss: 5.3606 | Time: 0.17s
# Batch 032/32 | Loss: 5.3103 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 6.2257
# Validation Loss : 5.2124
# Perplexity      : 183.53
# Training Time   : 16.47s
# Validation Time : 2.20s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 5.2124)
#
# ================ Epoch 2/50 ================
# Batch 001/32 | Loss: 5.3017 | Time: 0.28s
# Batch 002/32 | Loss: 5.3058 | Time: 0.17s
# Batch 003/32 | Loss: 5.2457 | Time: 0.18s
# Batch 004/32 | Loss: 5.3414 | Time: 0.17s
# Batch 005/32 | Loss: 5.2596 | Time: 0.17s
# Batch 006/32 | Loss: 5.3147 | Time: 0.17s
# Batch 007/32 | Loss: 5.2435 | Time: 0.18s
# Batch 008/32 | Loss: 5.2649 | Time: 0.18s
# Batch 009/32 | Loss: 5.2479 | Time: 0.17s
# Batch 010/32 | Loss: 5.2283 | Time: 0.20s
# Batch 011/32 | Loss: 5.2299 | Time: 0.18s
# Batch 012/32 | Loss: 5.2183 | Time: 0.18s
# Batch 013/32 | Loss: 5.2367 | Time: 0.21s
# Batch 014/32 | Loss: 5.2125 | Time: 0.18s
# Batch 015/32 | Loss: 5.2563 | Time: 0.19s
# Batch 016/32 | Loss: 5.2393 | Time: 0.18s
# Batch 017/32 | Loss: 5.2235 | Time: 0.19s
# Batch 018/32 | Loss: 5.1604 | Time: 0.18s
# Batch 019/32 | Loss: 5.1697 | Time: 0.17s
# Batch 020/32 | Loss: 5.2029 | Time: 0.20s
# Batch 021/32 | Loss: 5.1742 | Time: 0.18s
# Batch 022/32 | Loss: 5.2396 | Time: 0.17s
# Batch 023/32 | Loss: 5.1243 | Time: 0.19s
# Batch 024/32 | Loss: 5.1945 | Time: 0.19s
# Batch 025/32 | Loss: 5.1545 | Time: 0.17s
# Batch 026/32 | Loss: 5.1210 | Time: 0.17s
# Batch 027/32 | Loss: 5.1037 | Time: 0.19s
# Batch 028/32 | Loss: 5.1522 | Time: 0.17s
# Batch 029/32 | Loss: 5.0854 | Time: 0.17s
# Batch 030/32 | Loss: 5.1640 | Time: 0.19s
# Batch 031/32 | Loss: 5.1953 | Time: 0.19s
# Batch 032/32 | Loss: 5.0659 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 5.2087
# Validation Loss : 5.0314
# Perplexity      : 153.15
# Training Time   : 15.48s
# Validation Time : 2.21s
# GPU Memory Used : 1.75 GB
# ✓ Best model saved (Val Loss: 5.0314)
#
# ================ Epoch 3/50 ================
# Batch 001/32 | Loss: 5.1177 | Time: 0.24s
# Batch 002/32 | Loss: 5.0142 | Time: 0.18s
# Batch 003/32 | Loss: 5.0969 | Time: 0.18s
# Batch 004/32 | Loss: 5.1040 | Time: 0.17s
# Batch 005/32 | Loss: 5.1220 | Time: 0.17s
# Batch 006/32 | Loss: 5.0428 | Time: 0.17s
# Batch 007/32 | Loss: 5.0874 | Time: 0.21s
# Batch 008/32 | Loss: 5.0732 | Time: 0.19s
# Batch 009/32 | Loss: 5.0667 | Time: 0.21s
# Batch 010/32 | Loss: 5.0594 | Time: 0.18s
# Batch 011/32 | Loss: 5.0776 | Time: 0.22s
# Batch 012/32 | Loss: 5.0724 | Time: 0.20s
# Batch 013/32 | Loss: 5.0330 | Time: 0.19s
# Batch 014/32 | Loss: 5.0776 | Time: 0.18s
# Batch 015/32 | Loss: 5.0688 | Time: 0.21s
# Batch 016/32 | Loss: 5.0408 | Time: 0.20s
# Batch 017/32 | Loss: 5.0539 | Time: 0.17s
# Batch 018/32 | Loss: 5.1274 | Time: 0.19s
# Batch 019/32 | Loss: 5.0369 | Time: 0.18s
# Batch 020/32 | Loss: 5.0280 | Time: 0.18s
# Batch 021/32 | Loss: 5.0305 | Time: 0.19s
# Batch 022/32 | Loss: 5.0215 | Time: 0.19s
# Batch 023/32 | Loss: 5.0176 | Time: 0.19s
# Batch 024/32 | Loss: 4.9340 | Time: 0.18s
# Batch 025/32 | Loss: 5.0039 | Time: 0.17s
# Batch 026/32 | Loss: 5.0335 | Time: 0.18s
# Batch 027/32 | Loss: 5.0154 | Time: 0.18s
# Batch 028/32 | Loss: 5.0118 | Time: 0.19s
# Batch 029/32 | Loss: 4.9602 | Time: 0.18s
# Batch 030/32 | Loss: 4.8829 | Time: 0.18s
# Batch 031/32 | Loss: 4.9548 | Time: 0.18s
# Batch 032/32 | Loss: 4.9135 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 5.0369
# Validation Loss : 4.8435
# Perplexity      : 126.92
# Training Time   : 15.88s
# Validation Time : 2.21s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 4.8435)
#
# ================ Epoch 4/50 ================
# Batch 001/32 | Loss: 4.9436 | Time: 0.26s
# Batch 002/32 | Loss: 4.9482 | Time: 0.18s
# Batch 003/32 | Loss: 4.7962 | Time: 0.17s
# Batch 004/32 | Loss: 4.7958 | Time: 0.19s
# Batch 005/32 | Loss: 4.9078 | Time: 0.18s
# Batch 006/32 | Loss: 4.8972 | Time: 0.17s
# Batch 007/32 | Loss: 4.8357 | Time: 0.18s
# Batch 008/32 | Loss: 4.8762 | Time: 0.17s
# Batch 009/32 | Loss: 4.9268 | Time: 0.19s
# Batch 010/32 | Loss: 4.8692 | Time: 0.18s
# Batch 011/32 | Loss: 4.8640 | Time: 0.17s
# Batch 012/32 | Loss: 4.8844 | Time: 0.18s
# Batch 013/32 | Loss: 4.8552 | Time: 0.17s
# Batch 014/32 | Loss: 4.8034 | Time: 0.18s
# Batch 015/32 | Loss: 4.8776 | Time: 0.17s
# Batch 016/32 | Loss: 4.8487 | Time: 0.19s
# Batch 017/32 | Loss: 4.8441 | Time: 0.18s
# Batch 018/32 | Loss: 4.8817 | Time: 0.20s
#
# ---------------- Summary ----------------
# Train Loss      : 4.6850
# Validation Loss : 4.5431
# Perplexity      : 93.98
# Training Time   : 15.89s
# Validation Time : 2.24s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 4.5431)
#
# ================ Epoch 6/50 ================
# Batch 001/32 | Loss: 4.6642 | Time: 0.24s
# Batch 002/32 | Loss: 4.5662 | Time: 0.17s
# Batch 003/32 | Loss: 4.6089 | Time: 0.17s
# Batch 004/32 | Loss: 4.6560 | Time: 0.17s
# Batch 005/32 | Loss: 4.6023 | Time: 0.18s
# Batch 006/32 | Loss: 4.5552 | Time: 0.18s
# Batch 007/32 | Loss: 4.6362 | Time: 0.18s
# Batch 008/32 | Loss: 4.5219 | Time: 0.18s
# Batch 009/32 | Loss: 4.5721 | Time: 0.19s
# Batch 010/32 | Loss: 4.5592 | Time: 0.17s
# Batch 011/32 | Loss: 4.6080 | Time: 0.19s
# Batch 012/32 | Loss: 4.5606 | Time: 0.18s
# Batch 013/32 | Loss: 4.5836 | Time: 0.20s
# Batch 014/32 | Loss: 4.5674 | Time: 0.19s
# Batch 015/32 | Loss: 4.5670 | Time: 0.18s
# Batch 016/32 | Loss: 4.5838 | Time: 0.18s
# Batch 017/32 | Loss: 4.6360 | Time: 0.22s
# Batch 018/32 | Loss: 4.5421 | Time: 0.18s
# Batch 019/32 | Loss: 4.5984 | Time: 0.18s
# Batch 020/32 | Loss: 4.5605 | Time: 0.19s
# Batch 021/32 | Loss: 4.5088 | Time: 0.19s
# Batch 022/32 | Loss: 4.5898 | Time: 0.18s
# Batch 023/32 | Loss: 4.4734 | Time: 0.17s
# Batch 024/32 | Loss: 4.5061 | Time: 0.19s
# Batch 025/32 | Loss: 4.4897 | Time: 0.18s
# Batch 026/32 | Loss: 4.5159 | Time: 0.17s
# Batch 027/32 | Loss: 4.5569 | Time: 0.18s
# Batch 028/32 | Loss: 4.5690 | Time: 0.17s
# Batch 029/32 | Loss: 4.5017 | Time: 0.18s
# Batch 030/32 | Loss: 4.4880 | Time: 0.18s
# Batch 031/32 | Loss: 4.5616 | Time: 0.18s
# Batch 032/32 | Loss: 4.5583 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 4.5647
# Validation Loss : 4.4223
# Perplexity      : 83.28
# Training Time   : 15.16s
# Validation Time : 2.18s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 4.4223)
#
# ================ Epoch 7/50 ================
# Batch 001/32 | Loss: 4.4688 | Time: 0.26s
# Batch 002/32 | Loss: 4.4981 | Time: 0.19s
# Batch 003/32 | Loss: 4.4737 | Time: 0.18s
# Batch 004/32 | Loss: 4.4720 | Time: 0.18s
# Batch 005/32 | Loss: 4.5052 | Time: 0.18s
# Batch 006/32 | Loss: 4.4498 | Time: 0.17s
# Batch 007/32 | Loss: 4.4706 | Time: 0.19s
# Batch 008/32 | Loss: 4.3847 | Time: 0.18s
# Batch 009/32 | Loss: 4.5164 | Time: 0.17s
# Batch 024/32 | Loss: 4.2287 | Time: 0.19s
# Batch 025/32 | Loss: 4.2151 | Time: 0.19s
# Batch 026/32 | Loss: 4.2840 | Time: 0.17s
# Batch 027/32 | Loss: 4.2822 | Time: 0.19s
# Batch 028/32 | Loss: 4.2818 | Time: 0.19s
# Batch 029/32 | Loss: 4.2262 | Time: 0.17s
# Batch 030/32 | Loss: 4.2541 | Time: 0.18s
# Batch 031/32 | Loss: 4.1873 | Time: 0.17s
# Batch 032/32 | Loss: 4.2416 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 4.3135
# Validation Loss : 4.1732
# Perplexity      : 64.92
# Training Time   : 15.24s
# Validation Time : 2.25s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 4.1732)
#
# ================ Epoch 9/50 ================
# Batch 001/32 | Loss: 4.3375 | Time: 0.24s
# Batch 002/32 | Loss: 4.2914 | Time: 0.18s
# Batch 003/32 | Loss: 4.2597 | Time: 0.18s
# Batch 004/32 | Loss: 4.2366 | Time: 0.17s
# Batch 005/32 | Loss: 4.2603 | Time: 0.18s
# Batch 006/32 | Loss: 4.2513 | Time: 0.18s
# Batch 007/32 | Loss: 4.2190 | Time: 0.20s
# Batch 008/32 | Loss: 4.2646 | Time: 0.23s
# Batch 009/32 | Loss: 4.2562 | Time: 0.21s
# Batch 010/32 | Loss: 4.3216 | Time: 0.18s
# Batch 011/32 | Loss: 4.2803 | Time: 0.18s
# Batch 012/32 | Loss: 4.1069 | Time: 0.18s
# Batch 013/32 | Loss: 4.2715 | Time: 0.17s
# Batch 014/32 | Loss: 4.1675 | Time: 0.18s
# Batch 015/32 | Loss: 4.1543 | Time: 0.19s
# Batch 016/32 | Loss: 4.2043 | Time: 0.17s
# Batch 017/32 | Loss: 4.1626 | Time: 0.18s
# Batch 018/32 | Loss: 4.1422 | Time: 0.18s
# Batch 019/32 | Loss: 4.1382 | Time: 0.19s
# Batch 020/32 | Loss: 4.2565 | Time: 0.18s
# Batch 021/32 | Loss: 4.2156 | Time: 0.18s
# Batch 022/32 | Loss: 4.1153 | Time: 0.21s
# Batch 023/32 | Loss: 4.1751 | Time: 0.18s
# Batch 024/32 | Loss: 4.1002 | Time: 0.17s
# Batch 025/32 | Loss: 4.2573 | Time: 0.17s
# Batch 026/32 | Loss: 4.1166 | Time: 0.18s
# Batch 027/32 | Loss: 4.2080 | Time: 0.18s
# Batch 028/32 | Loss: 4.2511 | Time: 0.19s
# Batch 029/32 | Loss: 4.1587 | Time: 0.17s
# Batch 030/32 | Loss: 4.1904 | Time: 0.18s
# Batch 031/32 | Loss: 4.1432 | Time: 0.18s
# Batch 032/32 | Loss: 4.3020 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 4.2130
# Validation Loss : 4.0663
# Perplexity      : 58.34
# Training Time   : 15.68s
# Validation Time : 2.17s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 4.0663)
#
# ================ Epoch 10/50 ================
# Batch 015/32 | Loss: 4.0605 | Time: 0.20s
# Batch 016/32 | Loss: 4.0550 | Time: 0.18s
# Batch 017/32 | Loss: 4.0013 | Time: 0.17s
# Batch 018/32 | Loss: 4.0220 | Time: 0.18s
# Batch 019/32 | Loss: 4.0819 | Time: 0.17s
# Batch 020/32 | Loss: 3.9962 | Time: 0.19s
# Batch 021/32 | Loss: 4.0070 | Time: 0.18s
# Batch 022/32 | Loss: 3.9528 | Time: 0.18s
# Batch 023/32 | Loss: 4.0364 | Time: 0.17s
# Batch 024/32 | Loss: 3.9967 | Time: 0.18s
# Batch 025/32 | Loss: 4.1448 | Time: 0.17s
# Batch 026/32 | Loss: 4.0164 | Time: 0.18s
# Batch 027/32 | Loss: 4.0012 | Time: 0.18s
# Batch 028/32 | Loss: 4.0427 | Time: 0.18s
# Batch 029/32 | Loss: 3.9731 | Time: 0.18s
# Batch 030/32 | Loss: 3.9885 | Time: 0.19s
# Batch 031/32 | Loss: 4.0676 | Time: 0.17s
# Batch 032/32 | Loss: 4.0561 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 4.0465
# Validation Loss : 3.9222
# Perplexity      : 50.51
# Training Time   : 15.20s
# Validation Time : 2.23s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.9222)
#
# ================ Epoch 12/50 ================
# Batch 001/32 | Loss: 4.0104 | Time: 0.29s
# Batch 002/32 | Loss: 4.0279 | Time: 0.18s
# Batch 003/32 | Loss: 3.9302 | Time: 0.18s
# Batch 004/32 | Loss: 4.0384 | Time: 0.18s
# Batch 005/32 | Loss: 3.9532 | Time: 0.17s
# Batch 006/32 | Loss: 4.0405 | Time: 0.17s
# Batch 007/32 | Loss: 4.0419 | Time: 0.18s
# Batch 008/32 | Loss: 4.0308 | Time: 0.17s
# Batch 009/32 | Loss: 4.0378 | Time: 0.20s
# Batch 010/32 | Loss: 3.9907 | Time: 0.17s
# Batch 011/32 | Loss: 3.9832 | Time: 0.18s
# Batch 012/32 | Loss: 4.0885 | Time: 0.17s
# Batch 013/32 | Loss: 4.0593 | Time: 0.18s
# Batch 014/32 | Loss: 3.9370 | Time: 0.20s
# Batch 015/32 | Loss: 4.0681 | Time: 0.18s
# Batch 016/32 | Loss: 3.9754 | Time: 0.18s
# Batch 017/32 | Loss: 3.9764 | Time: 0.18s
# Batch 018/32 | Loss: 3.9941 | Time: 0.17s
# Batch 019/32 | Loss: 3.9199 | Time: 0.18s
# Batch 020/32 | Loss: 4.0001 | Time: 0.18s
# Batch 021/32 | Loss: 3.9794 | Time: 0.19s
# Batch 022/32 | Loss: 3.9023 | Time: 0.18s
# Batch 023/32 | Loss: 3.9246 | Time: 0.19s
# Batch 024/32 | Loss: 3.9089 | Time: 0.18s
# Batch 025/32 | Loss: 4.0005 | Time: 0.17s
# Batch 026/32 | Loss: 3.9551 | Time: 0.18s
# Batch 027/32 | Loss: 4.0139 | Time: 0.17s
# Batch 028/32 | Loss: 3.9025 | Time: 0.18s
# Batch 029/32 | Loss: 3.9157 | Time: 0.18s
# Batch 030/32 | Loss: 4.0621 | Time: 0.17s
# Batch 031/32 | Loss: 3.9104 | Time: 0.17s
# Batch 032/32 | Loss: 3.9514 | Time: 0.13s
#
# ---------------- Summary ----------------
# Train Loss      : 3.9853
# Validation Loss : 3.8777
# Perplexity      : 48.31
# Training Time   : 15.20s
# Validation Time : 2.26s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.8777)
#
# ================ Epoch 13/50 ================
# Batch 001/32 | Loss: 3.9343 | Time: 0.25s
# Batch 002/32 | Loss: 3.8660 | Time: 0.17s
# Batch 003/32 | Loss: 3.8883 | Time: 0.17s
# Batch 004/32 | Loss: 4.0169 | Time: 0.18s
# Batch 005/32 | Loss: 3.9800 | Time: 0.19s
# Batch 006/32 | Loss: 4.0410 | Time: 0.17s
# Batch 007/32 | Loss: 3.9265 | Time: 0.17s
# Batch 008/32 | Loss: 3.9950 | Time: 0.19s
# Batch 009/32 | Loss: 3.9173 | Time: 0.21s
# Batch 010/32 | Loss: 3.9331 | Time: 0.18s
# Batch 011/32 | Loss: 3.9299 | Time: 0.20s
# Batch 012/32 | Loss: 3.9629 | Time: 0.18s
# Batch 013/32 | Loss: 3.9205 | Time: 0.19s
# Batch 014/32 | Loss: 3.9065 | Time: 0.18s
# Batch 015/32 | Loss: 3.7719 | Time: 0.18s
# Batch 016/32 | Loss: 3.9521 | Time: 0.18s
# Batch 017/32 | Loss: 3.9359 | Time: 0.18s
# Batch 018/32 | Loss: 3.9477 | Time: 0.20s
# Batch 019/32 | Loss: 3.9279 | Time: 0.18s
# Batch 020/32 | Loss: 4.0036 | Time: 0.18s
# Batch 021/32 | Loss: 4.0272 | Time: 0.19s
# Batch 022/32 | Loss: 3.9765 | Time: 0.17s
# Batch 023/32 | Loss: 3.9682 | Time: 0.17s
# Batch 024/32 | Loss: 3.9759 | Time: 0.19s
# Batch 025/32 | Loss: 3.9174 | Time: 0.17s
# Batch 026/32 | Loss: 3.9378 | Time: 0.19s
# Batch 027/32 | Loss: 3.9661 | Time: 0.19s
# Batch 028/32 | Loss: 3.9137 | Time: 0.18s
# Batch 029/32 | Loss: 3.9043 | Time: 0.18s
# Batch 030/32 | Loss: 3.8091 | Time: 0.17s
# Batch 031/32 | Loss: 3.9473 | Time: 0.18s
# Batch 032/32 | Loss: 3.9543 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.9392
# Validation Loss : 3.8343
# Perplexity      : 46.26
# Training Time   : 16.34s
# Validation Time : 2.20s
# GPU Memory Used : 1.75 GB
# ✓ Best model saved (Val Loss: 3.8343)
#
# ================ Epoch 14/50 ================
# Batch 001/32 | Loss: 3.9255 | Time: 0.29s
# Batch 002/32 | Loss: 3.8618 | Time: 0.21s
# Batch 003/32 | Loss: 3.9517 | Time: 0.17s
# Batch 004/32 | Loss: 3.8666 | Time: 0.18s
# Batch 005/32 | Loss: 3.9685 | Time: 0.17s
# Batch 006/32 | Loss: 3.9272 | Time: 0.19s
# Batch 007/32 | Loss: 3.8430 | Time: 0.18s
# Batch 008/32 | Loss: 3.9400 | Time: 0.17s
# Batch 009/32 | Loss: 3.8601 | Time: 0.17s
# Batch 010/32 | Loss: 3.8368 | Time: 0.17s
# Batch 011/32 | Loss: 3.8827 | Time: 0.20s
# Batch 012/32 | Loss: 3.9057 | Time: 0.18s
# Batch 013/32 | Loss: 3.8992 | Time: 0.18s
# Batch 014/32 | Loss: 3.8480 | Time: 0.17s
# Batch 015/32 | Loss: 3.9254 | Time: 0.20s
# Batch 016/32 | Loss: 3.9741 | Time: 0.20s
# Batch 017/32 | Loss: 3.8599 | Time: 0.17s
# Batch 018/32 | Loss: 3.9011 | Time: 0.17s
# Batch 019/32 | Loss: 3.8627 | Time: 0.20s
# Batch 020/32 | Loss: 3.8264 | Time: 0.18s
# Batch 021/32 | Loss: 3.8900 | Time: 0.19s
# Batch 022/32 | Loss: 3.9233 | Time: 0.18s
# Batch 023/32 | Loss: 3.8126 | Time: 0.18s
# Batch 024/32 | Loss: 3.8682 | Time: 0.17s
# Batch 025/32 | Loss: 3.9600 | Time: 0.17s
# Batch 026/32 | Loss: 3.9344 | Time: 0.18s
# Batch 027/32 | Loss: 3.9759 | Time: 0.18s
# Batch 028/32 | Loss: 3.8980 | Time: 0.19s
# Batch 029/32 | Loss: 3.8816 | Time: 0.17s
# Batch 030/32 | Loss: 3.8276 | Time: 0.17s
# Batch 031/32 | Loss: 3.9329 | Time: 0.18s
# Batch 032/32 | Loss: 3.9431 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.8973
# Validation Loss : 3.7970
# Perplexity      : 44.57
# Training Time   : 15.59s
# Validation Time : 2.16s
# GPU Memory Used : 1.75 GB
# ✓ Best model saved (Val Loss: 3.7970)
#
# ================ Epoch 15/50 ================
# Batch 001/32 | Loss: 3.9132 | Time: 0.27s
# Batch 002/32 | Loss: 3.8338 | Time: 0.18s
# Batch 003/32 | Loss: 3.8728 | Time: 0.19s
# Batch 004/32 | Loss: 3.9580 | Time: 0.18s
# Batch 005/32 | Loss: 3.8534 | Time: 0.17s
# Batch 006/32 | Loss: 3.8760 | Time: 0.17s
# Batch 007/32 | Loss: 3.9015 | Time: 0.17s
# Batch 008/32 | Loss: 3.7837 | Time: 0.18s
# Batch 009/32 | Loss: 3.8596 | Time: 0.19s
# Batch 010/32 | Loss: 3.8315 | Time: 0.17s
# Batch 011/32 | Loss: 3.8408 | Time: 0.18s
# Batch 012/32 | Loss: 3.8548 | Time: 0.18s
# Batch 013/32 | Loss: 3.8692 | Time: 0.17s
# Batch 014/32 | Loss: 3.8479 | Time: 0.18s
# Batch 015/32 | Loss: 3.7796 | Time: 0.19s
# Batch 016/32 | Loss: 3.8611 | Time: 0.18s
# Batch 017/32 | Loss: 3.8705 | Time: 0.17s
# Batch 018/32 | Loss: 3.8348 | Time: 0.17s
# Batch 019/32 | Loss: 3.7512 | Time: 0.20s
# Batch 020/32 | Loss: 3.8895 | Time: 0.18s
# Batch 021/32 | Loss: 3.8741 | Time: 0.18s
# Batch 022/32 | Loss: 3.8609 | Time: 0.18s
# Batch 023/32 | Loss: 3.8805 | Time: 0.17s
# Batch 024/32 | Loss: 3.8908 | Time: 0.17s
# Batch 025/32 | Loss: 3.8451 | Time: 0.18s
# Batch 026/32 | Loss: 3.8421 | Time: 0.17s
# Batch 027/32 | Loss: 3.8690 | Time: 0.20s
# Batch 028/32 | Loss: 3.8236 | Time: 0.18s
# Batch 029/32 | Loss: 3.8960 | Time: 0.18s
# Batch 030/32 | Loss: 3.8629 | Time: 0.17s
# Batch 031/32 | Loss: 3.8273 | Time: 0.19s
# Batch 032/32 | Loss: 3.8548 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.8566
# Validation Loss : 3.7746
# Perplexity      : 43.58
# Training Time   : 15.75s
# Validation Time : 2.31s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.7746)
#
# ================ Epoch 16/50 ================
# Batch 001/32 | Loss: 3.7871 | Time: 0.20s
# Batch 002/32 | Loss: 3.7860 | Time: 0.19s
# Batch 003/32 | Loss: 3.8401 | Time: 0.18s
# Batch 004/32 | Loss: 3.7569 | Time: 0.17s
# Batch 005/32 | Loss: 3.8753 | Time: 0.18s
# Batch 006/32 | Loss: 3.8217 | Time: 0.18s
# Batch 007/32 | Loss: 3.8727 | Time: 0.19s
# Batch 008/32 | Loss: 3.8406 | Time: 0.18s
# Batch 009/32 | Loss: 3.8679 | Time: 0.20s
# Batch 010/32 | Loss: 3.8050 | Time: 0.18s
# Batch 011/32 | Loss: 3.7292 | Time: 0.18s
# Batch 012/32 | Loss: 3.8390 | Time: 0.18s
# Batch 013/32 | Loss: 3.8307 | Time: 0.18s
# Batch 014/32 | Loss: 3.7476 | Time: 0.17s
# Batch 015/32 | Loss: 3.8500 | Time: 0.17s
# Batch 016/32 | Loss: 3.8808 | Time: 0.20s
# Batch 017/32 | Loss: 3.8109 | Time: 0.19s
# Batch 018/32 | Loss: 3.9147 | Time: 0.18s
# Batch 019/32 | Loss: 3.7723 | Time: 0.19s
# Batch 020/32 | Loss: 3.8291 | Time: 0.19s
# Batch 021/32 | Loss: 3.8502 | Time: 0.19s
# Batch 022/32 | Loss: 3.8148 | Time: 0.18s
# Batch 023/32 | Loss: 3.7829 | Time: 0.20s
# Batch 024/32 | Loss: 3.8023 | Time: 0.17s
# Batch 025/32 | Loss: 3.8923 | Time: 0.17s
# Batch 026/32 | Loss: 3.8120 | Time: 0.18s
# Batch 027/32 | Loss: 3.7488 | Time: 0.20s
# Batch 028/32 | Loss: 3.8115 | Time: 0.18s
# Batch 029/32 | Loss: 3.8226 | Time: 0.17s
# Batch 030/32 | Loss: 3.8089 | Time: 0.17s
# Batch 031/32 | Loss: 3.8205 | Time: 0.18s
# Batch 032/32 | Loss: 3.7937 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.8193
# Validation Loss : 3.7478
# Perplexity      : 42.43
# Training Time   : 15.44s
# Validation Time : 2.23s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.7478)
#
# ================ Epoch 17/50 ================
# Batch 001/32 | Loss: 3.8830 | Time: 0.22s
# Batch 002/32 | Loss: 3.7693 | Time: 0.20s
# Batch 003/32 | Loss: 3.7591 | Time: 0.17s
# Batch 004/32 | Loss: 3.7505 | Time: 0.17s
# Batch 005/32 | Loss: 3.8433 | Time: 0.18s
# Batch 006/32 | Loss: 3.7457 | Time: 0.17s
# Batch 007/32 | Loss: 3.7605 | Time: 0.18s
# Batch 008/32 | Loss: 3.8199 | Time: 0.17s
# Batch 009/32 | Loss: 3.7667 | Time: 0.18s
# Batch 010/32 | Loss: 3.7069 | Time: 0.20s
# Batch 011/32 | Loss: 3.8476 | Time: 0.19s
# Batch 012/32 | Loss: 3.8235 | Time: 0.18s
# Batch 013/32 | Loss: 3.8352 | Time: 0.18s
# Batch 014/32 | Loss: 3.8628 | Time: 0.19s
# Batch 015/32 | Loss: 3.8393 | Time: 0.19s
# Batch 016/32 | Loss: 3.7430 | Time: 0.20s
# Batch 017/32 | Loss: 3.8125 | Time: 0.18s
# Batch 018/32 | Loss: 3.8146 | Time: 0.21s
# Batch 019/32 | Loss: 3.7512 | Time: 0.20s
# Batch 020/32 | Loss: 3.7179 | Time: 0.18s
# Batch 021/32 | Loss: 3.7962 | Time: 0.18s
# Batch 022/32 | Loss: 3.6549 | Time: 0.18s
# Batch 023/32 | Loss: 3.7972 | Time: 0.17s
# Batch 024/32 | Loss: 3.8204 | Time: 0.17s
# Batch 025/32 | Loss: 3.7520 | Time: 0.18s
# Batch 026/32 | Loss: 3.7724 | Time: 0.18s
# Batch 027/32 | Loss: 3.7606 | Time: 0.18s
# Batch 028/32 | Loss: 3.8217 | Time: 0.18s
# Batch 029/32 | Loss: 3.7686 | Time: 0.18s
# Batch 030/32 | Loss: 3.8505 | Time: 0.19s
# Batch 031/32 | Loss: 3.7759 | Time: 0.17s
# Batch 032/32 | Loss: 3.7705 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.7873
# Validation Loss : 3.7229
# Perplexity      : 41.38
# Training Time   : 14.89s
# Validation Time : 2.30s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.7229)
#
# ================ Epoch 18/50 ================
# Batch 001/32 | Loss: 3.7545 | Time: 0.22s
# Batch 002/32 | Loss: 3.7699 | Time: 0.18s
# Batch 003/32 | Loss: 3.7929 | Time: 0.18s
# Batch 004/32 | Loss: 3.7091 | Time: 0.18s
# Batch 005/32 | Loss: 3.8066 | Time: 0.19s
# Batch 006/32 | Loss: 3.7471 | Time: 0.17s
# Batch 007/32 | Loss: 3.8376 | Time: 0.22s
# Batch 008/32 | Loss: 3.7287 | Time: 0.21s
# Batch 009/32 | Loss: 3.7349 | Time: 0.19s
# Batch 010/32 | Loss: 3.8258 | Time: 0.18s
# Batch 025/32 | Loss: 3.7366 | Time: 0.18s
# Batch 026/32 | Loss: 3.7897 | Time: 0.18s
# Batch 027/32 | Loss: 3.6554 | Time: 0.17s
# Batch 028/32 | Loss: 3.7408 | Time: 0.19s
# Batch 029/32 | Loss: 3.6430 | Time: 0.19s
# Batch 030/32 | Loss: 3.6995 | Time: 0.17s
# Batch 031/32 | Loss: 3.8281 | Time: 0.19s
# Batch 032/32 | Loss: 3.6169 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.7335
# Validation Loss : 3.6924
# Perplexity      : 40.14
# Training Time   : 14.87s
# Validation Time : 2.24s
# GPU Memory Used : 1.75 GB
# ✓ Best model saved (Val Loss: 3.6924)
#
# ================ Epoch 20/50 ================
# Batch 001/32 | Loss: 3.7346 | Time: 0.28s
# Batch 002/32 | Loss: 3.6918 | Time: 0.18s
# Batch 003/32 | Loss: 3.8020 | Time: 0.18s
# Batch 004/32 | Loss: 3.7358 | Time: 0.18s
# Batch 005/32 | Loss: 3.7880 | Time: 0.17s
# Batch 006/32 | Loss: 3.7314 | Time: 0.18s
# Batch 007/32 | Loss: 3.7019 | Time: 0.20s
# Batch 008/32 | Loss: 3.6959 | Time: 0.18s
# Batch 009/32 | Loss: 3.6853 | Time: 0.21s
# Batch 010/32 | Loss: 3.6987 | Time: 0.19s
# Batch 011/32 | Loss: 3.7882 | Time: 0.18s
# Batch 012/32 | Loss: 3.6711 | Time: 0.18s
# Batch 013/32 | Loss: 3.6886 | Time: 0.18s
# Batch 014/32 | Loss: 3.6665 | Time: 0.19s
# Batch 015/32 | Loss: 3.6657 | Time: 0.20s
# Batch 016/32 | Loss: 3.6098 | Time: 0.23s
# Batch 017/32 | Loss: 3.7500 | Time: 0.19s
# Batch 018/32 | Loss: 3.6488 | Time: 0.18s
# Batch 019/32 | Loss: 3.8317 | Time: 0.19s
# Batch 020/32 | Loss: 3.7278 | Time: 0.17s
# Batch 021/32 | Loss: 3.7122 | Time: 0.19s
# Batch 022/32 | Loss: 3.6345 | Time: 0.17s
# Batch 023/32 | Loss: 3.6027 | Time: 0.18s
# Batch 024/32 | Loss: 3.7332 | Time: 0.17s
# Batch 025/32 | Loss: 3.7003 | Time: 0.18s
# Batch 026/32 | Loss: 3.7611 | Time: 0.17s
# Batch 027/32 | Loss: 3.7472 | Time: 0.17s
# Batch 028/32 | Loss: 3.7537 | Time: 0.19s
# Batch 029/32 | Loss: 3.7256 | Time: 0.18s
# Batch 030/32 | Loss: 3.7236 | Time: 0.18s
# Batch 031/32 | Loss: 3.6677 | Time: 0.17s
# Batch 032/32 | Loss: 3.8281 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 3.7157
# Validation Loss : 3.6721
# Perplexity      : 39.33
# Training Time   : 15.48s
# Validation Time : 2.24s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.6721)
#
# ================ Epoch 21/50 ================
# Batch 001/32 | Loss: 3.6746 | Time: 0.21s
# Batch 002/32 | Loss: 3.7600 | Time: 0.19s
# Batch 030/32 | Loss: 3.6639 | Time: 0.18s
# Batch 031/32 | Loss: 3.6844 | Time: 0.17s
# Batch 032/32 | Loss: 3.6723 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 3.6618
# Validation Loss : 3.6399
# Perplexity      : 38.09
# Training Time   : 15.15s
# Validation Time : 2.21s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.6399)
#
# ================ Epoch 24/50 ================
# Batch 001/32 | Loss: 3.6043 | Time: 0.22s
# Batch 002/32 | Loss: 3.6490 | Time: 0.19s
# Batch 003/32 | Loss: 3.6522 | Time: 0.17s
# Batch 004/32 | Loss: 3.5878 | Time: 0.18s
# Batch 005/32 | Loss: 3.7453 | Time: 0.17s
# Batch 006/32 | Loss: 3.6495 | Time: 0.19s
# Batch 007/32 | Loss: 3.6734 | Time: 0.17s
# Batch 008/32 | Loss: 3.5527 | Time: 0.18s
# Batch 009/32 | Loss: 3.6897 | Time: 0.21s
# Batch 010/32 | Loss: 3.6973 | Time: 0.18s
# Batch 011/32 | Loss: 3.6203 | Time: 0.18s
# Batch 012/32 | Loss: 3.6793 | Time: 0.21s
# Batch 013/32 | Loss: 3.7377 | Time: 0.18s
# Batch 014/32 | Loss: 3.6348 | Time: 0.17s
# Batch 015/32 | Loss: 3.6335 | Time: 0.18s
# Batch 016/32 | Loss: 3.6014 | Time: 0.17s
# Batch 017/32 | Loss: 3.7008 | Time: 0.20s
# Batch 018/32 | Loss: 3.6276 | Time: 0.19s
# Batch 019/32 | Loss: 3.6769 | Time: 0.19s
# Batch 020/32 | Loss: 3.6186 | Time: 0.20s
# Batch 021/32 | Loss: 3.7007 | Time: 0.18s
# Batch 022/32 | Loss: 3.5830 | Time: 0.18s
# Batch 023/32 | Loss: 3.6833 | Time: 0.18s
# Batch 024/32 | Loss: 3.6072 | Time: 0.18s
# Batch 025/32 | Loss: 3.6154 | Time: 0.18s
# Batch 026/32 | Loss: 3.6453 | Time: 0.18s
# Batch 027/32 | Loss: 3.5672 | Time: 0.19s
# Batch 028/32 | Loss: 3.6764 | Time: 0.18s
# Batch 029/32 | Loss: 3.5887 | Time: 0.18s
# Batch 030/32 | Loss: 3.6711 | Time: 0.18s
# Batch 031/32 | Loss: 3.6715 | Time: 0.17s
# Batch 032/32 | Loss: 3.6792 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.6475
# Validation Loss : 3.6295
# Perplexity      : 37.70
# Training Time   : 15.77s
# Validation Time : 2.19s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.6295)
#
# ================ Epoch 25/50 ================
# Batch 001/32 | Loss: 3.6123 | Time: 0.31s
# Batch 002/32 | Loss: 3.5994 | Time: 0.19s
# Batch 003/32 | Loss: 3.5691 | Time: 0.17s
# Batch 004/32 | Loss: 3.6578 | Time: 0.18s
# Batch 005/32 | Loss: 3.6143 | Time: 0.17s
# Batch 006/32 | Loss: 3.5959 | Time: 0.17s
# Batch 007/32 | Loss: 3.5968 | Time: 0.19s
# Batch 022/32 | Loss: 3.6298 | Time: 0.18s
# Batch 023/32 | Loss: 3.6329 | Time: 0.19s
# Batch 024/32 | Loss: 3.5596 | Time: 0.19s
# Batch 025/32 | Loss: 3.7066 | Time: 0.18s
# Batch 026/32 | Loss: 3.5455 | Time: 0.17s
# Batch 027/32 | Loss: 3.5748 | Time: 0.18s
# Batch 028/32 | Loss: 3.5509 | Time: 0.17s
# Batch 029/32 | Loss: 3.7292 | Time: 0.18s
# Batch 030/32 | Loss: 3.6426 | Time: 0.18s
# Batch 031/32 | Loss: 3.5979 | Time: 0.17s
# Batch 032/32 | Loss: 3.6345 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.6225
# Validation Loss : 3.6129
# Perplexity      : 37.07
# Training Time   : 15.19s
# Validation Time : 2.15s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.6129)
#
# ================ Epoch 27/50 ================
# Batch 001/32 | Loss: 3.6246 | Time: 0.21s
# Batch 002/32 | Loss: 3.6316 | Time: 0.18s
# Batch 003/32 | Loss: 3.5425 | Time: 0.19s
# Batch 004/32 | Loss: 3.6398 | Time: 0.17s
# Batch 005/32 | Loss: 3.6427 | Time: 0.19s
# Batch 006/32 | Loss: 3.6130 | Time: 0.19s
# Batch 007/32 | Loss: 3.5815 | Time: 0.18s
# Batch 008/32 | Loss: 3.6136 | Time: 0.19s
# Batch 009/32 | Loss: 3.5987 | Time: 0.18s
# Batch 010/32 | Loss: 3.5224 | Time: 0.18s
# Batch 011/32 | Loss: 3.5765 | Time: 0.20s
# Batch 012/32 | Loss: 3.6431 | Time: 0.17s
# Batch 013/32 | Loss: 3.5656 | Time: 0.17s
# Batch 014/32 | Loss: 3.4948 | Time: 0.19s
# Batch 015/32 | Loss: 3.6029 | Time: 0.17s
# Batch 016/32 | Loss: 3.6505 | Time: 0.18s
# Batch 017/32 | Loss: 3.6071 | Time: 0.18s
# Batch 018/32 | Loss: 3.5618 | Time: 0.22s
# Batch 019/32 | Loss: 3.6379 | Time: 0.17s
# Batch 020/32 | Loss: 3.5788 | Time: 0.17s
# Batch 021/32 | Loss: 3.6623 | Time: 0.17s
# Batch 022/32 | Loss: 3.7282 | Time: 0.18s
# Batch 023/32 | Loss: 3.6241 | Time: 0.18s
# Batch 024/32 | Loss: 3.5303 | Time: 0.18s
# Batch 025/32 | Loss: 3.5826 | Time: 0.17s
# Batch 026/32 | Loss: 3.6129 | Time: 0.19s
# Batch 027/32 | Loss: 3.5549 | Time: 0.18s
# Batch 028/32 | Loss: 3.5561 | Time: 0.17s
# Batch 029/32 | Loss: 3.6491 | Time: 0.18s
# Batch 030/32 | Loss: 3.6224 | Time: 0.18s
# Batch 031/32 | Loss: 3.6725 | Time: 0.19s
# Batch 032/32 | Loss: 3.7779 | Time: 0.12s
#
# ---------------- Summary ----------------
# Train Loss      : 3.6095
# Validation Loss : 3.6063
# Perplexity      : 36.83
# Training Time   : 15.05s
# Validation Time : 2.19s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.6063)
#
# ================ Epoch 28/50 ================
# Batch 001/32 | Loss: 3.6160 | Time: 0.27s
# Batch 002/32 | Loss: 3.5909 | Time: 0.17s
# Batch 003/32 | Loss: 3.5838 | Time: 0.17s
# Batch 004/32 | Loss: 3.5294 | Time: 0.18s
# Batch 005/32 | Loss: 3.5943 | Time: 0.18s
# Batch 006/32 | Loss: 3.6117 | Time: 0.19s
# Batch 007/32 | Loss: 3.5880 | Time: 0.19s
# Batch 008/32 | Loss: 3.5090 | Time: 0.19s
# Batch 009/32 | Loss: 3.6083 | Time: 0.18s
# Batch 010/32 | Loss: 3.5992 | Time: 0.18s
# Batch 011/32 | Loss: 3.6093 | Time: 0.18s
# Batch 012/32 | Loss: 3.6893 | Time: 0.18s
# Batch 013/32 | Loss: 3.5760 | Time: 0.18s
# Batch 014/32 | Loss: 3.5548 | Time: 0.17s
# Batch 015/32 | Loss: 3.5008 | Time: 0.18s
# Batch 016/32 | Loss: 3.5962 | Time: 0.17s
# Batch 017/32 | Loss: 3.6964 | Time: 0.19s
# Batch 018/32 | Loss: 3.5993 | Time: 0.20s
# Batch 019/32 | Loss: 3.5548 | Time: 0.18s
# Batch 020/32 | Loss: 3.4993 | Time: 0.18s
# Batch 021/32 | Loss: 3.6134 | Time: 0.17s
# Batch 022/32 | Loss: 3.6236 | Time: 0.18s
# Batch 023/32 | Loss: 3.5663 | Time: 0.18s
# Batch 024/32 | Loss: 3.5219 | Time: 0.17s
# Batch 025/32 | Loss: 3.6116 | Time: 0.18s
# Batch 026/32 | Loss: 3.5661 | Time: 0.19s
# Batch 027/32 | Loss: 3.6096 | Time: 0.17s
# Batch 028/32 | Loss: 3.6141 | Time: 0.17s
# Batch 029/32 | Loss: 3.6478 | Time: 0.22s
# Batch 030/32 | Loss: 3.6072 | Time: 0.18s
# Batch 031/32 | Loss: 3.5825 | Time: 0.17s
# Batch 032/32 | Loss: 3.5652 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.5886
# Validation Loss : 3.5981
# Perplexity      : 36.53
# Training Time   : 14.76s
# Validation Time : 2.15s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.5981)
#
# ================ Epoch 29/50 ================
# Batch 001/32 | Loss: 3.5858 | Time: 0.20s
# Batch 002/32 | Loss: 3.5615 | Time: 0.18s
# Batch 003/32 | Loss: 3.5587 | Time: 0.17s
# Batch 004/32 | Loss: 3.5297 | Time: 0.18s
# Batch 005/32 | Loss: 3.6694 | Time: 0.18s
# Batch 006/32 | Loss: 3.6097 | Time: 0.18s
# Batch 007/32 | Loss: 3.6036 | Time: 0.18s
# Batch 008/32 | Loss: 3.5525 | Time: 0.18s
# Batch 009/32 | Loss: 3.6007 | Time: 0.17s
# Batch 010/32 | Loss: 3.6108 | Time: 0.19s
# Batch 011/32 | Loss: 3.5647 | Time: 0.18s
# Batch 012/32 | Loss: 3.5632 | Time: 0.19s
# Batch 013/32 | Loss: 3.5026 | Time: 0.17s
# Batch 014/32 | Loss: 3.5554 | Time: 0.21s
# Batch 015/32 | Loss: 3.6014 | Time: 0.19s
# Batch 016/32 | Loss: 3.6430 | Time: 0.17s
# Batch 017/32 | Loss: 3.5601 | Time: 0.19s
# Batch 018/32 | Loss: 3.5838 | Time: 0.20s
# Batch 019/32 | Loss: 3.7046 | Time: 0.17s
# Batch 020/32 | Loss: 3.6453 | Time: 0.18s
# Batch 021/32 | Loss: 3.6085 | Time: 0.18s
# Batch 022/32 | Loss: 3.6323 | Time: 0.19s
# Batch 023/32 | Loss: 3.5963 | Time: 0.18s
# Batch 024/32 | Loss: 3.5391 | Time: 0.19s
# Batch 025/32 | Loss: 3.5905 | Time: 0.17s
# Batch 026/32 | Loss: 3.4873 | Time: 0.17s
# Batch 027/32 | Loss: 3.5179 | Time: 0.18s
# Batch 028/32 | Loss: 3.5923 | Time: 0.17s
# Batch 029/32 | Loss: 3.5040 | Time: 0.17s
# Batch 030/32 | Loss: 3.5475 | Time: 0.19s
# Batch 031/32 | Loss: 3.4006 | Time: 0.17s
# Batch 032/32 | Loss: 3.5680 | Time: 0.11s
#
# ---------------- Summary ----------------
# Train Loss      : 3.5747
# Validation Loss : 3.5903
# Perplexity      : 36.25
# Training Time   : 15.56s
# Validation Time : 2.28s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.5903)
#
# ================ Epoch 30/50 ================
# Batch 001/32 | Loss: 3.5812 | Time: 0.21s
# Batch 002/32 | Loss: 3.6027 | Time: 0.21s
# Batch 003/32 | Loss: 3.5250 | Time: 0.18s
# Batch 004/32 | Loss: 3.6428 | Time: 0.18s
# Batch 005/32 | Loss: 3.5567 | Time: 0.18s
# Batch 006/32 | Loss: 3.5542 | Time: 0.19s
# Batch 007/32 | Loss: 3.5183 | Time: 0.19s
# Batch 008/32 | Loss: 3.5721 | Time: 0.18s
# Batch 009/32 | Loss: 3.5673 | Time: 0.18s
# Batch 010/32 | Loss: 3.7046 | Time: 0.21s
# Batch 011/32 | Loss: 3.5528 | Time: 0.18s
# Batch 012/32 | Loss: 3.5630 | Time: 0.17s
# Batch 013/32 | Loss: 3.5868 | Time: 0.17s
# Batch 014/32 | Loss: 3.4717 | Time: 0.19s
# Batch 015/32 | Loss: 3.5471 | Time: 0.18s
# Batch 016/32 | Loss: 3.5788 | Time: 0.19s
# Batch 017/32 | Loss: 3.6248 | Time: 0.19s
# Batch 018/32 | Loss: 3.5293 | Time: 0.17s
# Batch 019/32 | Loss: 3.4444 | Time: 0.17s
# ...
# Batch 038/125 | Loss: 3.6197 | Time: 0.21s
# Batch 039/125 | Loss: 3.6540 | Time: 0.25s
# Batch 040/125 | Loss: 3.5732 | Time: 0.25s
# Batch 041/125 | Loss: 3.6367 | Time: 0.26s
# Batch 042/125 | Loss: 3.6769 | Time: 0.19s
# Batch 043/125 | Loss: 3.5065 | Time: 0.27s
# Batch 044/125 | Loss: 3.6405 | Time: 0.21s
# Batch 095/125 | Loss: 3.4670 | Time: 0.27s
# Batch 096/125 | Loss: 3.5434 | Time: 0.28s
# Batch 097/125 | Loss: 3.5988 | Time: 0.23s
# Batch 098/125 | Loss: 3.5203 | Time: 0.20s
# Batch 099/125 | Loss: 3.5694 | Time: 0.21s
# Batch 100/125 | Loss: 3.5928 | Time: 0.20s
# Batch 101/125 | Loss: 3.6821 | Time: 0.20s
# Batch 102/125 | Loss: 3.6058 | Time: 0.20s
# Batch 103/125 | Loss: 3.6284 | Time: 0.20s
# Batch 104/125 | Loss: 3.6383 | Time: 0.24s
# Batch 105/125 | Loss: 3.6702 | Time: 0.23s
# Batch 106/125 | Loss: 3.5557 | Time: 0.20s
# Batch 107/125 | Loss: 3.7004 | Time: 0.22s
# Batch 108/125 | Loss: 3.6326 | Time: 0.23s
# Batch 109/125 | Loss: 3.5987 | Time: 0.20s
# Batch 110/125 | Loss: 3.5215 | Time: 0.20s
# Batch 111/125 | Loss: 3.6114 | Time: 0.19s
# Batch 112/125 | Loss: 3.5402 | Time: 0.21s
# Batch 113/125 | Loss: 3.6175 | Time: 0.20s
# Batch 114/125 | Loss: 3.5636 | Time: 0.21s
# Batch 115/125 | Loss: 3.6845 | Time: 0.23s
# Batch 116/125 | Loss: 3.5825 | Time: 0.20s
# Batch 117/125 | Loss: 3.4824 | Time: 0.20s
# Batch 118/125 | Loss: 3.5571 | Time: 0.20s
# Batch 119/125 | Loss: 3.6307 | Time: 0.24s
# Batch 120/125 | Loss: 3.6397 | Time: 0.20s
# Batch 121/125 | Loss: 3.5783 | Time: 0.22s
# Batch 122/125 | Loss: 3.5600 | Time: 0.20s
# Batch 123/125 | Loss: 3.6511 | Time: 0.25s
# Batch 124/125 | Loss: 3.6371 | Time: 0.20s
# Batch 125/125 | Loss: 3.5687 | Time: 0.09s
#
# ---------------- Summary ----------------
# Train Loss      : 3.5923
# Validation Loss : 3.8838
# Perplexity      : 48.61
# Training Time   : 53.93s
# Validation Time : 5.21s
# GPU Memory Used : 1.76 GB
# ✓ Best model saved (Val Loss: 3.8838)
#
# ================ Epoch 49/50 ================
# Batch 001/125 | Loss: 3.5860 | Time: 0.28s
# Batch 002/125 | Loss: 3.5492 | Time: 0.21s
# Batch 003/125 | Loss: 3.5796 | Time: 0.23s
# Batch 004/125 | Loss: 3.5704 | Time: 0.20s
# Batch 005/125 | Loss: 3.5583 | Time: 0.19s
# Batch 006/125 | Loss: 3.5553 | Time: 0.20s
# Batch 007/125 | Loss: 3.5820 | Time: 0.21s
# Batch 008/125 | Loss: 3.5590 | Time: 0.21s
# Batch 009/125 | Loss: 3.7429 | Time: 0.20s
# Batch 010/125 | Loss: 3.6140 | Time: 0.20s
# Batch 011/125 | Loss: 3.5665 | Time: 0.19s
# Batch 012/125 | Loss: 3.6250 | Time: 0.22s
# Batch 013/125 | Loss: 3.6444 | Time: 0.21s
# Batch 014/125 | Loss: 3.5686 | Time: 0.20s
# Batch 015/125 | Loss: 3.5625 | Time: 0.22s
# Batch 118/125 | Loss: 3.5644 | Time: 0.21s
# Batch 119/125 | Loss: 3.5600 | Time: 0.21s
# Batch 120/125 | Loss: 3.6072 | Time: 0.19s
# Batch 121/125 | Loss: 3.5973 | Time: 0.20s
# Batch 122/125 | Loss: 3.6199 | Time: 0.21s
# Batch 123/125 | Loss: 3.5749 | Time: 0.21s
# Batch 124/125 | Loss: 3.5577 | Time: 0.22s
# Batch 125/125 | Loss: 3.5961 | Time: 0.09s
#
# ---------------- Summary ----------------
# Train Loss      : 3.5893
# Validation Loss : 3.8838
# Perplexity      : 48.61
# Training Time   : 54.88s
# Validation Time : 5.19s
# GPU Memory Used : 1.75 GB
# No improvement for 1/8 epochs
#
# ================ Epoch 50/50 ================
# Batch 001/125 | Loss: 3.6047 | Time: 0.28s
# Batch 002/125 | Loss: 3.6020 | Time: 0.22s
# Batch 003/125 | Loss: 3.5381 | Time: 0.20s
# Batch 004/125 | Loss: 3.6337 | Time: 0.26s
# Batch 005/125 | Loss: 3.5522 | Time: 0.22s
# Batch 006/125 | Loss: 3.5751 | Time: 0.21s
# Batch 007/125 | Loss: 3.6105 | Time: 0.30s
# Batch 008/125 | Loss: 3.6930 | Time: 0.27s
# Batch 009/125 | Loss: 3.6603 | Time: 0.34s
# Batch 010/125 | Loss: 3.6031 | Time: 0.24s
# Batch 011/125 | Loss: 3.6676 | Time: 0.25s
# Batch 012/125 | Loss: 3.5635 | Time: 0.21s
# Batch 013/125 | Loss: 3.5963 | Time: 0.20s
# Batch 014/125 | Loss: 3.5824 | Time: 0.20s
# Batch 015/125 | Loss: 3.5977 | Time: 0.20s
# Batch 016/125 | Loss: 3.5292 | Time: 0.29s
# Batch 017/125 | Loss: 3.6280 | Time: 0.31s
# Batch 018/125 | Loss: 3.5825 | Time: 0.21s
# Batch 019/125 | Loss: 3.5880 | Time: 0.27s
# Batch 020/125 | Loss: 3.6197 | Time: 0.22s
# Batch 021/125 | Loss: 3.5740 | Time: 0.19s
# Batch 022/125 | Loss: 3.5905 | Time: 0.28s
# Batch 023/125 | Loss: 3.6358 | Time: 0.22s
# Batch 024/125 | Loss: 3.5440 | Time: 0.23s
# Batch 025/125 | Loss: 3.6322 | Time: 0.23s
# Batch 026/125 | Loss: 3.4967 | Time: 0.20s
# Batch 027/125 | Loss: 3.6040 | Time: 0.25s
# Batch 028/125 | Loss: 3.5809 | Time: 0.28s
# Batch 029/125 | Loss: 3.5958 | Time: 0.22s
# Batch 030/125 | Loss: 3.6012 | Time: 0.23s
# Batch 031/125 | Loss: 3.5030 | Time: 0.26s
# Batch 032/125 | Loss: 3.6185 | Time: 0.20s
# Batch 033/125 | Loss: 3.5439 | Time: 0.20s
# Batch 034/125 | Loss: 3.6287 | Time: 0.21s
# Batch 035/125 | Loss: 3.6008 | Time: 0.20s
# Batch 036/125 | Loss: 3.5368 | Time: 0.21s
# Batch 037/125 | Loss: 3.6180 | Time: 0.25s
# Batch 038/125 | Loss: 3.6247 | Time: 0.30s
# Batch 090/125 | Loss: 3.5418 | Time: 0.24s
# Batch 091/125 | Loss: 3.6060 | Time: 0.26s
# Batch 092/125 | Loss: 3.6580 | Time: 0.21s
# Batch 093/125 | Loss: 3.5160 | Time: 0.19s
# Batch 094/125 | Loss: 3.5726 | Time: 0.20s
# Batch 095/125 | Loss: 3.5936 | Time: 0.22s
# Batch 096/125 | Loss: 3.6083 | Time: 0.22s
# Batch 097/125 | Loss: 3.6899 | Time: 0.20s
# Batch 098/125 | Loss: 3.5999 | Time: 0.20s
# Batch 099/125 | Loss: 3.6043 | Time: 0.24s
# Batch 100/125 | Loss: 3.6118 | Time: 0.26s
# Batch 101/125 | Loss: 3.7125 | Time: 0.21s
# Batch 102/125 | Loss: 3.5777 | Time: 0.21s
# Batch 103/125 | Loss: 3.5868 | Time: 0.20s
# Batch 104/125 | Loss: 3.6552 | Time: 0.22s
# Batch 105/125 | Loss: 3.5779 | Time: 0.22s
# Batch 106/125 | Loss: 3.6491 | Time: 0.20s
# Batch 107/125 | Loss: 3.5179 | Time: 0.20s
# Batch 108/125 | Loss: 3.5953 | Time: 0.20s
# Batch 109/125 | Loss: 3.5615 | Time: 0.25s
# Batch 110/125 | Loss: 3.5951 | Time: 0.20s
# Batch 111/125 | Loss: 3.5944 | Time: 0.21s
# Batch 112/125 | Loss: 3.7076 | Time: 0.22s
# Batch 113/125 | Loss: 3.5664 | Time: 0.23s
# Batch 114/125 | Loss: 3.5736 | Time: 0.19s
# Batch 115/125 | Loss: 3.6220 | Time: 0.22s
# Batch 116/125 | Loss: 3.5767 | Time: 0.19s
# Batch 117/125 | Loss: 3.4988 | Time: 0.20s
# Batch 118/125 | Loss: 3.6379 | Time: 0.20s
# Batch 119/125 | Loss: 3.5656 | Time: 0.21s
# Batch 120/125 | Loss: 3.5555 | Time: 0.21s
# Batch 121/125 | Loss: 3.5191 | Time: 0.20s
# Batch 122/125 | Loss: 3.5466 | Time: 0.20s
# Batch 123/125 | Loss: 3.5910 | Time: 0.22s
# Batch 124/125 | Loss: 3.4981 | Time: 0.19s
# Batch 125/125 | Loss: 3.7368 | Time: 0.10s
#
# ---------------- Summary ----------------
# Train Loss      : 3.5934
# Validation Loss : 3.8840
# Perplexity      : 48.62
# Training Time   : 52.91s
# Validation Time : 5.10s
# GPU Memory Used : 1.76 GB
# No improvement for 2/8 epochs
# Generating captions...
# [' A girl is on rollerskates talking on her cellphone standing in a parking lot .', ' A trendy girl talking on her cellphone while gliding slowly down the street .', ' A young adult wearing rollerblades , holding a cellular phone to her ear .', ' there is a young girl on her cellphone while skating .', ' Woman talking on cellphone and wearing rollerskates .']
# ['a woman in a blue shirt and blue jeans is walking down the street']
#     Metric     Score
# 0   BLEU-1  0.462641
# 1   BLEU-2  0.316839
# 2   BLEU-3  0.214716
# 3   BLEU-4  0.139175
# 4  ROUGE-L  0.406431
# 5   METEOR  0.368403
# 6    CIDEr  0.306666
# Memory after cleanup
# Allocated: 1.1974225044250488
# Reserved: 3.685546875
